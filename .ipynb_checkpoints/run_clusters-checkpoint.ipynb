# %%
file = 0
for i in range (1,14):
    file = i
    # %run clean_data.ipynb
    # %run write_clusters.ipynb
# Out:
# read_data/read_data_1.csv
# success!
# success!
# read_data/read_data_2.csv
# success!
# success!
# read_data/read_data_3.csv
# success!
# success!
# read_data/read_data_4.csv
# success!
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~/Documents/GitHub/REU/write_clusters.ipynb in <module>
#       6 kmeans = KMeans(n_clusters=30)
#       7 kmeans.fit(x)
# ----> 8 identified_clusters = kmeans.fit_predict(x)
#       9 centroids = kmeans.cluster_centers_
#      10 labels = kmeans.labels_
#
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/cluster/_kmeans.py in fit_predict(self, X, y, sample_weight)
#    1120             Index of the cluster each sample belongs to.
#    1121         """
# -> 1122         return self.fit(X, sample_weight=sample_weight).labels_
#    1123
#    1124     def fit_transform(self, X, y=None, sample_weight=None):
#
# ...
